# %% [markdown]
# # f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30
#
# # Определить корни
#
# # Найти интервалы, на которых функция возрастает
#
# # Найти интервалы, на которых функция убывает
#
# # Построить график
#
# # Вычислить вершину
#
# # Определить промежутки, на котором f > 0
#
# # Определить промежутки, на котором f < 0

# %% [markdown]
# 1. Определить корни

# %%
from sympy import solveset
from sympy.abc import x, y
solveset(-12*x**4*sin(cos(x)) - 18*x**3+5*x**2 + 10*x - 30, x)
# Out:
# ConditionSet(x, Eq(-12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30, 0), Complexes)

# %% [markdown]
# 2. Найти интервалы, на которых функция возрастает

# %%
from sympy import is_decreasing, is_increasing
from sympy import S, Interval, oo, sin, cos

is_increasing(-12*x**4*sin(cos(x)) - 18*x**3+5*x**2 + 10*x - 30, Interval.open(100, 100))
# Out:
# True

# %% [markdown]
# 3. Найти интервалы, на которых функция убывает

# %%
from sympy import is_decreasing, is_increasing
from sympy import S, Interval, oo, sin, cos

is_decreasing(-12*x**4*sin(cos(x)) - 18*x**3+5*x**2 + 10*x - 30, Interval.open(100, 100))
# Out:
# True

# %% [markdown]
# 4. Построить график

# %%
import sympy
from sympy import *
x = symbols('x')

plot(-12*x**4*sin(cos(x)) - 18*x**3+5*x**2 + 10*x - 30, (x, -100, 100))

# %%
# 5. Вычислить вершину
# x = -b/2a - вершина функции
# x = 0

from sympy import Interval, Symbol, minimum, S
minimum(-12*x**4*sin(cos(x)) - 18*x**3+5*x**2 + 10*x - 30, x)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Input In [3], in <cell line: 6>()
#       1 # 5. Вычислить вершину
#       2 # x = -b/2a - вершина функции
#       3 # x = 0
#       5 from sympy import Interval, Symbol, minimum, S
# ----> 6 minimum(-12*x**4*sin(cos(x)) - 18*x**3+5*x**2 + 10*x - 30, x)
#
# File ~\anaconda3\lib\site-packages\sympy\calculus\util.py:837, in minimum(f, symbol, domain)
#     834     if domain is S.EmptySet:
#     835         raise ValueError("Minimum value not defined for empty domain.")
# --> 837     return function_range(f, symbol, domain).inf
#     838 else:
#     839     raise ValueError("%s is not a valid symbol." % symbol)
#
# File ~\anaconda3\lib\site-packages\sympy\calculus\util.py:200, in function_range(f, symbol, domain)
#     197 solution = solveset(f.diff(symbol), symbol, interval)
#     199 if not iterable(solution):
# ...

# %% [markdown]
# 6. Определить промежутки, на котором f(y) > 0
#
# 7. Определить промежутки, на котором f(y) < 0

# %%
from sympy import sin, cos
i = -2

while i < 5:
    res = -12*(i**4)*sin(cos(i)) - 18*(i**3)+5*(i**2) + 10*i - 30
    print(f'{i:5} {res}')
    i += 0.25
# Out:
#    -2 114 - 192*sin(cos(2))
# -1.75 84.2362264434217
#  -1.5 22.7062978600371
# -1.25 -8.61688348015826
#  -1.0 -23.1727431022826
# -0.75 -29.6305454063462
#  -0.5 -32.0768972661308
# -0.25 -31.9448876758491
#   0.0 -30
#  0.25 -27.5073876758491
#   0.5 -26.5768972661308
#  0.75 -29.8180454063462
#   1.0 -39.1727431022826
#  1.25 -53.9293834801583
#   1.5 -68.7937021399629
#  1.75 -73.7012735565783
#   2.0 -56.3860824603650
#  2.25 -6.48328903644182
#   2.5 81.6339310551285
#  2.75 208.771407169284
#   3.0 371.613249414674
#  3.25 559.699259919839
#   3.5 744.937914855306
#  3.75 864.542372520439
#   4.0 806.031005616432
#  4.25 410.135963499851
#   4.5 -494.391372399966
#  4.75 -2028.43103731620
